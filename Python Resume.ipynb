# %% [markdown]
# ![smartphone.png](attachment:smartphone.png)

# %%
import matplotlib.pyplot as plt


plt.rcParams.update({'font.family':'Helvetica'})
fig, ax = plt.subplots(figsize=(8.5, 11))

#color settings
green = '#3A6152'
black = '#3C3F42'
white = '#f1f1f1'

#color blocking
plt.axvline(x=.01, color=green, alpha=0.7, linewidth=300)

#removing axes
plt.axis('off')
ax.set_facecolor(white)



firstName = 'Juliana'
lastName = 'Cannon'
title1 = 'Data Science '
title2 = 'and Analytics'
loc = 'Stillwater, OK'
phoneNum = '(405)501-0733'
email = 'juliana.cannon@okstate.edu'
header1 = 'Education'
header2 = 'Experience'
header3 = 'References'
header4 = 'Skills'
uni = 'Oklahoma State University (2019-2022)'
major = 'B.S. Actuarial and Financial Mathematics'
minor = '- Minor: Applied Computer Programming'
gpa = 'GPA: 3.9'
subHeader1 = "- Relevant Coursework: "
course1 = '- Mathematical Statistics'
course2 = '- Mathematical Modeling'
course3 = '- Python Programming'
work1 = 'Kay Jewelers (2019-Present)'
work2 = 'Math Learning Success Center (Fall 2021)'
pos1 ='Store Assistant Manager'
respon1 = '- Analyzing and improving work procedures to maximize'
respon2 = 'efficiency.'
respon3 = '- Hiring and training individuals with high potential.'
respon4 = '- Communcating clearly and concisely with team members'
respon5 = 'and management.'
respon6 = '- Ensuring guests\' unique needs are met and exceeded'
respon7 = 'in a timely manner.'
pos2 = 'Math Tutor'
respon8 = '- Quickly analyzing problems at hand and deciding the best'
respon9 = 'approach to a solution.'
respon10 = '- Digesting constructive feedback and implementing it'
respon11 = 'in a timely manner.'
respon12 = '- Quickly adapting to different styles of communication.'
ref1 = 'Kelsey Schwartz'
refPos1 = 'District Manager, Kay Jewelers'
refEmail1 = '- kelsey.schwartz@signetjewelers.com'
ref2 = 'Lauren Lowery'
refPos2 = 'Store Manager, Kay Jewelers'
refEmail2 = '- lauren.lowery@signetjewelers.com'
skill1 = '- Microsoft Suite'
skill2 = '- Python*'
skill3 = '- Java'
skill4 = '- Sage'
skill5 = '- LaTeX'
skill6 = '- Data visualization'
skill7 = '- Analytical mindset'
skill8 = '- Experience with R'
skill9 = '- Experience with ArcGIS'
#Contact info
plt.annotate(firstName, (.02,.94), weight ='bold', fontsize=28, color=white)
plt.annotate(lastName, (.02,.89), weight ='bold', fontsize=28, color=white)
plt.annotate(title1, (.02,.85), weight ='normal', fontsize=14, color=white)
plt.annotate(title2, (.02,.82), weight ='normal', fontsize=14, color=white)
plt.annotate(loc, (.02,.76), weight ='normal', fontsize=10, color=white)
plt.annotate(phoneNum, (.02,.72), weight ='normal', fontsize=10, color=white)
plt.annotate(email, (.02,.68), weight ='normal', fontsize=10, color=white)

#Note
plt.annotate('* This resume was generated entirely in Python. For \n full source code visit my GitHub.',(.35, .96), weight ='normal', fontsize=10, color=green)

#Education
plt.annotate(header1, (.35,.92), weight ='bold', fontsize=18, color=green)
plt.axhline(y=.91,xmin = .35,xmax =.98, color = green, alpha=1, linewidth=2)
plt.annotate(uni, (.35,.87), weight ='bold', fontsize=12, color=black)
plt.text(.35, .84, major, style='italic',color=black,fontsize=10)
plt.text(.85, .84, gpa, style='italic',color=black,fontsize=10)
plt.annotate(minor, (.35, .81), weight = 'normal', fontsize = 10, color = black)
plt.annotate(subHeader1, (.35, .78), weight = 'normal', fontsize = 10, color = black)
plt.annotate(course1, (.37, .76), weight = 'normal', fontsize = 8, color = black)
plt.annotate(course2, (.37, .74), weight = 'normal', fontsize = 8, color = black)
plt.annotate(course3, (.37, .72), weight = 'normal', fontsize = 8, color = black)

#Experience
plt.annotate(header2, (.35,.67), weight ='bold', fontsize=18, color=green)
plt.axhline(y=.66,xmin = .35,xmax =.98, color = green, alpha=1, linewidth=2)
plt.annotate(work1, (.35,.62), weight ='bold', fontsize=12, color=black)
plt.text(.35, .59, pos1, style='italic',color=black,fontsize=10)
plt.annotate(respon1, (.35, .56), weight = 'normal', fontsize = 10, color = black)
plt.annotate(respon2, (.365, .54), weight = 'normal', fontsize = 10, color = black)
plt.annotate(respon3, (.35, .52), weight = 'normal', fontsize = 10, color = black)
plt.annotate(respon4, (.35, .50), weight = 'normal', fontsize = 10, color = black)
plt.annotate(respon5, (.365, .48), weight = 'normal', fontsize = 10, color = black)
plt.annotate(respon6, (.35, .46), weight = 'normal', fontsize = 10, color = black)
plt.annotate(respon7, (.365, .44), weight = 'normal', fontsize = 10, color = black)

plt.annotate(work2, (.35,.41), weight ='bold', fontsize=12, color=black)
plt.text(.35, .38, pos2, style='italic',color=black,fontsize=10)
plt.annotate(respon8, (.35, .35), weight = 'normal', fontsize = 10, color = black)
plt.annotate(respon9, (.365, .33), weight = 'normal', fontsize = 10, color = black)
plt.annotate(respon10, (.35, .31), weight = 'normal', fontsize = 10, color = black)
plt.annotate(respon11, (.365, .29), weight = 'normal', fontsize = 10, color = black)
plt.annotate(respon12, (.35, .27), weight = 'normal', fontsize = 10, color = black)

#References
plt.annotate(header3, (.35,.22), weight ='bold', fontsize=18, color=green)
plt.axhline(y=.21,xmin = .35,xmax =.98, color = green, alpha=1, linewidth=2)
plt.annotate(ref1, (.35,.18), weight ='bold', fontsize=12, color=black)
plt.text(.35, .15, refPos1, style='italic',color=black,fontsize=10)
plt.annotate(refEmail1, (.35, .12), weight = 'normal', fontsize = 10, color = black)

plt.annotate(ref2, (.35,.09), weight ='bold', fontsize=12, color=black)
plt.text(.35, .06, refPos2, style='italic',color=black,fontsize=10)
plt.annotate(refEmail2, (.35, .03), weight = 'normal', fontsize = 10, color = black)

#Skills
plt.annotate(header4, (.02,.61), weight ='bold', fontsize=18, color=white)
plt.axhline(y=.60,xmin = .02,xmax =.31, color = white, alpha=1, linewidth=2)
plt.annotate(skill1, (.02, .57), weight = 'normal', fontsize = 10, color = white)
plt.annotate(skill2, (.02, .54), weight = 'normal', fontsize = 10, color = white)
plt.annotate(skill3, (.02, .51), weight = 'normal', fontsize = 10, color = white)
plt.annotate(skill4, (.02, .48), weight = 'normal', fontsize = 10, color = white)
plt.annotate(skill5, (.02, .45), weight = 'normal', fontsize = 10, color = white)
plt.annotate(skill6, (.02, .42), weight = 'normal', fontsize = 10, color = white)
plt.annotate(skill7, (.02, .39), weight = 'normal', fontsize = 10, color = white)
plt.annotate(skill8, (.02, .36), weight = 'normal', fontsize = 10, color = white)
plt.annotate(skill9, (.02, .33), weight = 'normal', fontsize = 10, color = white)

#add qr code
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
qrCode = mpimg.imread('./downloads/frame.png')
imagebox = OffsetImage(qrCode, zoom=0.25)
ab = AnnotationBbox(imagebox, (0.165, 0.195))
ax.add_artist(ab)

plt.annotate("Visit my GitHub", (.07, .10), weight = 'bold', fontsize = 10, color = white)




plt.savefig('pythonResume.pdf', dpi=300, bbox_inches='tight')
